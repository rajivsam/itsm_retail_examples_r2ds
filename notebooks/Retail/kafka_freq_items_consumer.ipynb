# %%
from confluent_kafka import Consumer, KafkaException
from confluent_kafka.schema_registry.json_schema import JSONDeserializer
from confluent_kafka.serialization import SerializationContext, MessageField
from datasketches import frequent_strings_sketch, frequent_items_error_type
import uuid

config = { 'bootstrap.servers': 'localhost:19092','group.id':'demand_consumer_group' + str(uuid.uuid4()),
          'auto.offset.reset': "earliest"
     }

k = 10
fi = frequent_strings_sketch(k)

# %%
class DailyDemand(object):
    def __init__(self, day_of_year, year, demand):
        self._day_of_year = day_of_year 
        self._year = year
        self._demand = demand

# %%
schema_str = """{
    "$schema": "https://json-schema.org/draft/2020-12/schema",
    "title": "Daily_Demand",
    "description": "Daily Demand of SKUs",
    "type": "object",
    "properties": {
      "day_of_year": {
        "description": "day of the year",
        "type": "number"
      },
      "year": {
        "description": "year for which demand is encoded",
        "type": "number"
      },
      "demand": {
        "description": "composite object listing demand for each SKU as a key",
        "type": "object"
      }
    }
  }"""

# %%
def dict_to_demand(daily_demand, ctx):
    """
    Returns a dict representation of a User instance for serialization.

    Args:
        daily_demand (DailyDemand): DailyDemand instance.

        ctx (SerializationContext): Metadata pertaining to the serialization
            operation.

    Returns:
        dict: Dict populated with daily_demand attributes to be serialized.
    """
    if daily_demand is None:
        return None

    return DailyDemand(day_of_year=daily_demand['day_of_year'],
                year=daily_demand['year'], demand=daily_demand['demand'])

# %%
topic = "DAILY_DEMAND"
consumer = Consumer(config)
consumer.subscribe([topic])

# %%
def assignment_callback(consumer, partitions):
    for p in partitions:
        print(f'Assigned to {p.topic}, partition {p.partition}')

# %%
consumer = Consumer(config)
consumer.subscribe(['DAILY_DEMAND'], on_assign=assignment_callback)
json_deserializer = JSONDeserializer(schema_str,
                                         from_dict=dict_to_demand)
consumer.subscribe([topic])

# %%
    try:
        while True:
            msg = consumer.poll(1.0)
            if msg is None:
                continue

            dd = json_deserializer(msg.value(), SerializationContext(msg.topic(), MessageField.VALUE))

            if dd is not None:
                print("Daily Demand record record : {}\n"
                      "\t day of year: {}\n"
                      "\t year: {}\n"
                      .format(msg.key(), dd._day_of_year,
                              dd._year))
                dd_info = dd._demand
                for sku, demand in dd_info.items():
                    fi.update(sku, int(demand))
        
    except KeyboardInterrupt:
        print('Canceled by user.')
    finally:
        consumer.close()
# Out:
# Daily Demand record record : b'day 11 of 2010'
# 	 day of year: 11
# 	 year: 2010
#
# Daily Demand record record : b'day 30 of 2010'
# 	 day of year: 30
# 	 year: 2010
#
# Daily Demand record record : b'day 32 of 2010'
# 	 day of year: 32
# 	 year: 2010
#
# Daily Demand record record : b'day 43 of 2010'
# 	 day of year: 43
# 	 year: 2010
#
# Daily Demand record record : b'day 45 of 2010'
# 	 day of year: 45
# 	 year: 2010
#
# Daily Demand record record : b'day 55 of 2010'
# 	 day of year: 55
# 	 year: 2010
#
# Daily Demand record record : b'day 64 of 2010'
# 	 day of year: 64
# 	 year: 2010
#
# Daily Demand record record : b'day 66 of 2010'
# 	 day of year: 66
# 	 year: 2010
#
# Daily Demand record record : b'day 68 of 2010'
# 	 day of year: 68
# 	 year: 2010
#
# Daily Demand record record : b'day 72 of 2010'
# 	 day of year: 72
# 	 year: 2010
#
# Daily Demand record record : b'day 11 of 2010'
# 	 day of year: 11
# 	 year: 2010
#
# Daily Demand record record : b'day 30 of 2010'
# 	 day of year: 30
# 	 year: 2010
#
# Daily Demand record record : b'day 32 of 2010'
# 	 day of year: 32
# 	 year: 2010
#
# Daily Demand record record : b'day 43 of 2010'
# 	 day of year: 43
# 	 year: 2010
#
# Daily Demand record record : b'day 45 of 2010'
# 	 day of year: 45
# 	 year: 2010
#
# Daily Demand record record : b'day 55 of 2010'
# 	 day of year: 55
# 	 year: 2010
#
# Daily Demand record record : b'day 64 of 2010'
# 	 day of year: 64
# 	 year: 2010
#
# Daily Demand record record : b'day 66 of 2010'
# 	 day of year: 66
# 	 year: 2010
#
# Daily Demand record record : b'day 68 of 2010'
# 	 day of year: 68
# 	 year: 2010
#
# Daily Demand record record : b'day 72 of 2010'
# 	 day of year: 72
# 	 year: 2010
#
# Daily Demand record record : b'day 11 of 2010'
# 	 day of year: 11
# 	 year: 2010
#
# Daily Demand record record : b'day 30 of 2010'
# 	 day of year: 30
# 	 year: 2010
#
# Daily Demand record record : b'day 32 of 2010'
# 	 day of year: 32
# 	 year: 2010
#
# Daily Demand record record : b'day 43 of 2010'
# 	 day of year: 43
# 	 year: 2010
#
# Daily Demand record record : b'day 45 of 2010'
# 	 day of year: 45
# 	 year: 2010
#
# Daily Demand record record : b'day 55 of 2010'
# 	 day of year: 55
# 	 year: 2010
#
# Daily Demand record record : b'day 64 of 2010'
# 	 day of year: 64
# 	 year: 2010
#
# Daily Demand record record : b'day 66 of 2010'
# 	 day of year: 66
# 	 year: 2010
#
# Daily Demand record record : b'day 68 of 2010'
# 	 day of year: 68
# 	 year: 2010
#
# Daily Demand record record : b'day 72 of 2010'
# 	 day of year: 72
# 	 year: 2010
#
# Daily Demand record record : b'day 1 of 2010'
# 	 day of year: 1
# 	 year: 2010
#
# Daily Demand record record : b'day 5 of 2010'
# 	 day of year: 5
# 	 year: 2010
#
# Daily Demand record record : b'day 7 of 2010'
# 	 day of year: 7
# 	 year: 2010
#
# Daily Demand record record : b'day 12 of 2010'
# 	 day of year: 12
# 	 year: 2010
#
# Daily Demand record record : b'day 21 of 2010'
# 	 day of year: 21
# 	 year: 2010
#
# Daily Demand record record : b'day 27 of 2010'
# 	 day of year: 27
# 	 year: 2010
#
# Daily Demand record record : b'day 29 of 2010'
# 	 day of year: 29
# 	 year: 2010
#
# Daily Demand record record : b'day 35 of 2010'
# 	 day of year: 35
# 	 year: 2010
#
# Daily Demand record record : b'day 48 of 2010'
# 	 day of year: 48
# 	 year: 2010
#
# Daily Demand record record : b'day 50 of 2010'
# 	 day of year: 50
# 	 year: 2010
#
# Daily Demand record record : b'day 61 of 2010'
# 	 day of year: 61
# 	 year: 2010
#
# Daily Demand record record : b'day 69 of 2010'
# 	 day of year: 69
# 	 year: 2010
#
# Daily Demand record record : b'day 1 of 2010'
# 	 day of year: 1
# 	 year: 2010
#
# Daily Demand record record : b'day 5 of 2010'
# 	 day of year: 5
# 	 year: 2010
#
# Daily Demand record record : b'day 7 of 2010'
# 	 day of year: 7
# 	 year: 2010
#
# Daily Demand record record : b'day 12 of 2010'
# 	 day of year: 12
# 	 year: 2010
#
# Daily Demand record record : b'day 21 of 2010'
# 	 day of year: 21
# 	 year: 2010
#
# Daily Demand record record : b'day 27 of 2010'
# 	 day of year: 27
# 	 year: 2010
#
# Daily Demand record record : b'day 29 of 2010'
# 	 day of year: 29
# 	 year: 2010
#
# Daily Demand record record : b'day 35 of 2010'
# 	 day of year: 35
# 	 year: 2010
#
# Daily Demand record record : b'day 48 of 2010'
# 	 day of year: 48
# 	 year: 2010
#
# Daily Demand record record : b'day 50 of 2010'
# 	 day of year: 50
# 	 year: 2010
#
# Daily Demand record record : b'day 61 of 2010'
# 	 day of year: 61
# 	 year: 2010
#
# Daily Demand record record : b'day 2 of 2010'
# 	 day of year: 2
# 	 year: 2010
#
# Daily Demand record record : b'day 4 of 2010'
# 	 day of year: 4
# 	 year: 2010
#
# Daily Demand record record : b'day 13 of 2010'
# 	 day of year: 13
# 	 year: 2010
#
# Daily Demand record record : b'day 19 of 2010'
# 	 day of year: 19
# 	 year: 2010
#
# Daily Demand record record : b'day 28 of 2010'
# 	 day of year: 28
# 	 year: 2010
#
# Daily Demand record record : b'day 34 of 2010'
# 	 day of year: 34
# 	 year: 2010
#
# Daily Demand record record : b'day 47 of 2010'
# 	 day of year: 47
# 	 year: 2010
#
# Daily Demand record record : b'day 49 of 2010'
# 	 day of year: 49
# 	 year: 2010
#
# Daily Demand record record : b'day 51 of 2010'
# 	 day of year: 51
# 	 year: 2010
#
# Daily Demand record record : b'day 53 of 2010'
# 	 day of year: 53
# 	 year: 2010
#
# Daily Demand record record : b'day 59 of 2010'
# 	 day of year: 59
# 	 year: 2010
#
# Daily Demand record record : b'day 70 of 2010'
# 	 day of year: 70
# 	 year: 2010
#
# Daily Demand record record : b'day 74 of 2010'
# 	 day of year: 74
# 	 year: 2010
#
# Daily Demand record record : b'day 2 of 2010'
# 	 day of year: 2
# 	 year: 2010
#
# Daily Demand record record : b'day 4 of 2010'
# 	 day of year: 4
# 	 year: 2010
#
# Daily Demand record record : b'day 13 of 2010'
# 	 day of year: 13
# 	 year: 2010
#
# Daily Demand record record : b'day 19 of 2010'
# 	 day of year: 19
# 	 year: 2010
#
# Daily Demand record record : b'day 28 of 2010'
# 	 day of year: 28
# 	 year: 2010
#
# Daily Demand record record : b'day 34 of 2010'
# 	 day of year: 34
# 	 year: 2010
#
# Daily Demand record record : b'day 47 of 2010'
# 	 day of year: 47
# 	 year: 2010
#
# Daily Demand record record : b'day 49 of 2010'
# 	 day of year: 49
# 	 year: 2010
#
# Daily Demand record record : b'day 51 of 2010'
# 	 day of year: 51
# 	 year: 2010
#
# Daily Demand record record : b'day 53 of 2010'
# 	 day of year: 53
# 	 year: 2010
#
# Daily Demand record record : b'day 3 of 2010'
# 	 day of year: 3
# 	 year: 2010
#
# Daily Demand record record : b'day 9 of 2010'
# 	 day of year: 9
# 	 year: 2010
#
# Daily Demand record record : b'day 18 of 2010'
# 	 day of year: 18
# 	 year: 2010
#
# Daily Demand record record : b'day 23 of 2010'
# 	 day of year: 23
# 	 year: 2010
#
# Daily Demand record record : b'day 33 of 2010'
# 	 day of year: 33
# 	 year: 2010
#
# Daily Demand record record : b'day 39 of 2010'
# 	 day of year: 39
# 	 year: 2010
#
# Daily Demand record record : b'day 42 of 2010'
# 	 day of year: 42
# 	 year: 2010
#
# Daily Demand record record : b'day 52 of 2010'
# 	 day of year: 52
# 	 year: 2010
#
# Daily Demand record record : b'day 54 of 2010'
# 	 day of year: 54
# 	 year: 2010
#
# Daily Demand record record : b'day 56 of 2010'
# 	 day of year: 56
# 	 year: 2010
#
# Daily Demand record record : b'day 63 of 2010'
# 	 day of year: 63
# 	 year: 2010
#
# Daily Demand record record : b'day 67 of 2010'
# 	 day of year: 67
# 	 year: 2010
#
# Daily Demand record record : b'day 71 of 2010'
# 	 day of year: 71
# 	 year: 2010
#
# Daily Demand record record : b'day 3 of 2010'
# 	 day of year: 3
# 	 year: 2010
#
# Daily Demand record record : b'day 9 of 2010'
# 	 day of year: 9
# 	 year: 2010
#
# Daily Demand record record : b'day 18 of 2010'
# 	 day of year: 18
# 	 year: 2010
#
# Daily Demand record record : b'day 23 of 2010'
# 	 day of year: 23
# 	 year: 2010
#
# Daily Demand record record : b'day 33 of 2010'
# 	 day of year: 33
# 	 year: 2010
#
# Daily Demand record record : b'day 39 of 2010'
# 	 day of year: 39
# 	 year: 2010
#
# Daily Demand record record : b'day 42 of 2010'
# 	 day of year: 42
# 	 year: 2010
#
# Daily Demand record record : b'day 52 of 2010'
# 	 day of year: 52
# 	 year: 2010
#
# Daily Demand record record : b'day 54 of 2010'
# 	 day of year: 54
# 	 year: 2010
#
# Daily Demand record record : b'day 56 of 2010'
# 	 day of year: 56
# 	 year: 2010
#
# Daily Demand record record : b'day 0 of 2010'
# 	 day of year: 0
# 	 year: 2010
#
# Daily Demand record record : b'day 6 of 2010'
# 	 day of year: 6
# 	 year: 2010
#
# Daily Demand record record : b'day 8 of 2010'
# 	 day of year: 8
# 	 year: 2010
#
# Daily Demand record record : b'day 15 of 2010'
# 	 day of year: 15
# 	 year: 2010
#
# Daily Demand record record : b'day 17 of 2010'
# 	 day of year: 17
# 	 year: 2010
#
# Daily Demand record record : b'day 20 of 2010'
# 	 day of year: 20
# 	 year: 2010
#
# Daily Demand record record : b'day 22 of 2010'
# 	 day of year: 22
# 	 year: 2010
#
# Daily Demand record record : b'day 24 of 2010'
# 	 day of year: 24
# 	 year: 2010
#
# Daily Demand record record : b'day 26 of 2010'
# 	 day of year: 26
# 	 year: 2010
#
# Daily Demand record record : b'day 36 of 2010'
# 	 day of year: 36
# 	 year: 2010
#
# Daily Demand record record : b'day 38 of 2010'
# 	 day of year: 38
# 	 year: 2010
#
# Daily Demand record record : b'day 41 of 2010'
# 	 day of year: 41
# 	 year: 2010
#
# Daily Demand record record : b'day 57 of 2010'
# 	 day of year: 57
# 	 year: 2010
#
# Daily Demand record record : b'day 60 of 2010'
# 	 day of year: 60
# 	 year: 2010
#
# Daily Demand record record : b'day 62 of 2010'
# 	 day of year: 62
# 	 year: 2010
#
# Daily Demand record record : b'day 0 of 2010'
# 	 day of year: 0
# 	 year: 2010
#
# Daily Demand record record : b'day 6 of 2010'
# 	 day of year: 6
# 	 year: 2010
#
# Daily Demand record record : b'day 8 of 2010'
# 	 day of year: 8
# 	 year: 2010
#
# Daily Demand record record : b'day 15 of 2010'
# 	 day of year: 15
# 	 year: 2010
#
# Daily Demand record record : b'day 17 of 2010'
# 	 day of year: 17
# 	 year: 2010
#
# Daily Demand record record : b'day 20 of 2010'
# 	 day of year: 20
# 	 year: 2010
#
# Daily Demand record record : b'day 22 of 2010'
# 	 day of year: 22
# 	 year: 2010
#
# Daily Demand record record : b'day 24 of 2010'
# 	 day of year: 24
# 	 year: 2010
#
# Daily Demand record record : b'day 10 of 2010'
# 	 day of year: 10
# 	 year: 2010
#
# Daily Demand record record : b'day 14 of 2010'
# 	 day of year: 14
# 	 year: 2010
#
# Daily Demand record record : b'day 16 of 2010'
# 	 day of year: 16
# 	 year: 2010
#
# Daily Demand record record : b'day 25 of 2010'
# 	 day of year: 25
# 	 year: 2010
#
# Daily Demand record record : b'day 31 of 2010'
# 	 day of year: 31
# 	 year: 2010
#
# Daily Demand record record : b'day 37 of 2010'
# 	 day of year: 37
# 	 year: 2010
#
# Daily Demand record record : b'day 40 of 2010'
# 	 day of year: 40
# 	 year: 2010
#
# Daily Demand record record : b'day 44 of 2010'
# 	 day of year: 44
# 	 year: 2010
#
# Daily Demand record record : b'day 46 of 2010'
# 	 day of year: 46
# 	 year: 2010
#
# Daily Demand record record : b'day 58 of 2010'
# 	 day of year: 58
# 	 year: 2010
#
# Daily Demand record record : b'day 65 of 2010'
# 	 day of year: 65
# 	 year: 2010
#
# Daily Demand record record : b'day 73 of 2010'
# 	 day of year: 73
# 	 year: 2010
#
# Daily Demand record record : b'day 10 of 2010'
# 	 day of year: 10
# 	 year: 2010
#
# Daily Demand record record : b'day 14 of 2010'
# 	 day of year: 14
# 	 year: 2010
#
# Daily Demand record record : b'day 16 of 2010'
# 	 day of year: 16
# 	 year: 2010
#
# Daily Demand record record : b'day 25 of 2010'
# 	 day of year: 25
# 	 year: 2010
#
# Daily Demand record record : b'day 31 of 2010'
# 	 day of year: 31
# 	 year: 2010
#
# Daily Demand record record : b'day 37 of 2010'
# 	 day of year: 37
# 	 year: 2010
#
# Daily Demand record record : b'day 40 of 2010'
# 	 day of year: 40
# 	 year: 2010
#
# Daily Demand record record : b'day 44 of 2010'
# 	 day of year: 44
# 	 year: 2010
#
# Daily Demand record record : b'day 46 of 2010'
# 	 day of year: 46
# 	 year: 2010
#
# Daily Demand record record : b'day 58 of 2010'
# 	 day of year: 58
# 	 year: 2010
#
# Daily Demand record record : b'day 65 of 2010'
# 	 day of year: 65
# 	 year: 2010
#
# Daily Demand record record : b'day 69 of 2010'
# 	 day of year: 69
# 	 year: 2010
#
# Daily Demand record record : b'day 1 of 2010'
# 	 day of year: 1
# 	 year: 2010
#
# Daily Demand record record : b'day 5 of 2010'
# 	 day of year: 5
# 	 year: 2010
#
# Daily Demand record record : b'day 7 of 2010'
# 	 day of year: 7
# 	 year: 2010
#
# Daily Demand record record : b'day 12 of 2010'
# 	 day of year: 12
# 	 year: 2010
#
# Daily Demand record record : b'day 21 of 2010'
# 	 day of year: 21
# 	 year: 2010
#
# Daily Demand record record : b'day 27 of 2010'
# 	 day of year: 27
# 	 year: 2010
#
# Daily Demand record record : b'day 29 of 2010'
# 	 day of year: 29
# 	 year: 2010
#
# Daily Demand record record : b'day 35 of 2010'
# 	 day of year: 35
# 	 year: 2010
#
# Daily Demand record record : b'day 48 of 2010'
# 	 day of year: 48
# 	 year: 2010
#
# Daily Demand record record : b'day 50 of 2010'
# 	 day of year: 50
# 	 year: 2010
#
# Daily Demand record record : b'day 61 of 2010'
# 	 day of year: 61
# 	 year: 2010
#
# Daily Demand record record : b'day 69 of 2010'
# 	 day of year: 69
# 	 year: 2010
#
# Daily Demand record record : b'day 59 of 2010'
# 	 day of year: 59
# 	 year: 2010
#
# Daily Demand record record : b'day 70 of 2010'
# 	 day of year: 70
# 	 year: 2010
#
# Daily Demand record record : b'day 74 of 2010'
# 	 day of year: 74
# 	 year: 2010
#
# Daily Demand record record : b'day 2 of 2010'
# 	 day of year: 2
# 	 year: 2010
#
# Daily Demand record record : b'day 4 of 2010'
# 	 day of year: 4
# 	 year: 2010
#
# Daily Demand record record : b'day 13 of 2010'
# 	 day of year: 13
# 	 year: 2010
#
# Daily Demand record record : b'day 19 of 2010'
# 	 day of year: 19
# 	 year: 2010
#
# Daily Demand record record : b'day 28 of 2010'
# 	 day of year: 28
# 	 year: 2010
#
# Daily Demand record record : b'day 34 of 2010'
# 	 day of year: 34
# 	 year: 2010
#
# Daily Demand record record : b'day 47 of 2010'
# 	 day of year: 47
# 	 year: 2010
#
# Daily Demand record record : b'day 49 of 2010'
# 	 day of year: 49
# 	 year: 2010
#
# Daily Demand record record : b'day 51 of 2010'
# 	 day of year: 51
# 	 year: 2010
#
# Daily Demand record record : b'day 53 of 2010'
# 	 day of year: 53
# 	 year: 2010
#
# Daily Demand record record : b'day 59 of 2010'
# 	 day of year: 59
# 	 year: 2010
#
# Daily Demand record record : b'day 70 of 2010'
# 	 day of year: 70
# 	 year: 2010
#
# Daily Demand record record : b'day 74 of 2010'
# 	 day of year: 74
# 	 year: 2010
#
# Daily Demand record record : b'day 63 of 2010'
# 	 day of year: 63
# 	 year: 2010
#
# Daily Demand record record : b'day 67 of 2010'
# 	 day of year: 67
# 	 year: 2010
#
# Daily Demand record record : b'day 71 of 2010'
# 	 day of year: 71
# 	 year: 2010
#
# Daily Demand record record : b'day 3 of 2010'
# 	 day of year: 3
# 	 year: 2010
#
# Daily Demand record record : b'day 9 of 2010'
# 	 day of year: 9
# 	 year: 2010
#
# Daily Demand record record : b'day 18 of 2010'
# 	 day of year: 18
# 	 year: 2010
#
# Daily Demand record record : b'day 23 of 2010'
# 	 day of year: 23
# 	 year: 2010
#
# Daily Demand record record : b'day 33 of 2010'
# 	 day of year: 33
# 	 year: 2010
#
# Daily Demand record record : b'day 39 of 2010'
# 	 day of year: 39
# 	 year: 2010
#
# Daily Demand record record : b'day 42 of 2010'
# 	 day of year: 42
# 	 year: 2010
#
# Daily Demand record record : b'day 52 of 2010'
# 	 day of year: 52
# 	 year: 2010
#
# Daily Demand record record : b'day 54 of 2010'
# 	 day of year: 54
# 	 year: 2010
#
# Daily Demand record record : b'day 56 of 2010'
# 	 day of year: 56
# 	 year: 2010
#
# Daily Demand record record : b'day 63 of 2010'
# 	 day of year: 63
# 	 year: 2010
#
# Daily Demand record record : b'day 67 of 2010'
# 	 day of year: 67
# 	 year: 2010
#
# Daily Demand record record : b'day 71 of 2010'
# 	 day of year: 71
# 	 year: 2010
#
# Daily Demand record record : b'day 26 of 2010'
# 	 day of year: 26
# 	 year: 2010
#
# Daily Demand record record : b'day 36 of 2010'
# 	 day of year: 36
# 	 year: 2010
#
# Daily Demand record record : b'day 38 of 2010'
# 	 day of year: 38
# 	 year: 2010
#
# Daily Demand record record : b'day 41 of 2010'
# 	 day of year: 41
# 	 year: 2010
#
# Daily Demand record record : b'day 57 of 2010'
# 	 day of year: 57
# 	 year: 2010
#
# Daily Demand record record : b'day 60 of 2010'
# 	 day of year: 60
# 	 year: 2010
#
# Daily Demand record record : b'day 62 of 2010'
# 	 day of year: 62
# 	 year: 2010
#
# Daily Demand record record : b'day 0 of 2010'
# 	 day of year: 0
# 	 year: 2010
#
# Daily Demand record record : b'day 6 of 2010'
# 	 day of year: 6
# 	 year: 2010
#
# Daily Demand record record : b'day 8 of 2010'
# 	 day of year: 8
# 	 year: 2010
#
# Daily Demand record record : b'day 15 of 2010'
# 	 day of year: 15
# 	 year: 2010
#
# Daily Demand record record : b'day 17 of 2010'
# 	 day of year: 17
# 	 year: 2010
#
# Daily Demand record record : b'day 20 of 2010'
# 	 day of year: 20
# 	 year: 2010
#
# Daily Demand record record : b'day 22 of 2010'
# 	 day of year: 22
# 	 year: 2010
#
# Daily Demand record record : b'day 24 of 2010'
# 	 day of year: 24
# 	 year: 2010
#
# Daily Demand record record : b'day 26 of 2010'
# 	 day of year: 26
# 	 year: 2010
#
# Daily Demand record record : b'day 36 of 2010'
# 	 day of year: 36
# 	 year: 2010
#
# Daily Demand record record : b'day 38 of 2010'
# 	 day of year: 38
# 	 year: 2010
#
# Daily Demand record record : b'day 41 of 2010'
# 	 day of year: 41
# 	 year: 2010
#
# Daily Demand record record : b'day 57 of 2010'
# 	 day of year: 57
# 	 year: 2010
#
# Daily Demand record record : b'day 60 of 2010'
# 	 day of year: 60
# 	 year: 2010
#
# Daily Demand record record : b'day 62 of 2010'
# 	 day of year: 62
# 	 year: 2010
#
# Daily Demand record record : b'day 73 of 2010'
# 	 day of year: 73
# 	 year: 2010
#
# Daily Demand record record : b'day 10 of 2010'
# 	 day of year: 10
# 	 year: 2010
#
# Daily Demand record record : b'day 14 of 2010'
# 	 day of year: 14
# 	 year: 2010
#
# Daily Demand record record : b'day 16 of 2010'
# 	 day of year: 16
# 	 year: 2010
#
# Daily Demand record record : b'day 25 of 2010'
# 	 day of year: 25
# 	 year: 2010
#
# Daily Demand record record : b'day 31 of 2010'
# 	 day of year: 31
# 	 year: 2010
#
# Daily Demand record record : b'day 37 of 2010'
# 	 day of year: 37
# 	 year: 2010
#
# Daily Demand record record : b'day 40 of 2010'
# 	 day of year: 40
# 	 year: 2010
#
# Daily Demand record record : b'day 44 of 2010'
# 	 day of year: 44
# 	 year: 2010
#
# Daily Demand record record : b'day 46 of 2010'
# 	 day of year: 46
# 	 year: 2010
#
# Daily Demand record record : b'day 58 of 2010'
# 	 day of year: 58
# 	 year: 2010
#
# Daily Demand record record : b'day 65 of 2010'
# 	 day of year: 65
# 	 year: 2010
#
# Daily Demand record record : b'day 73 of 2010'
# 	 day of year: 73
# 	 year: 2010
#
# Canceled by user.

# %%
import pandas as pd
fp = "../../data/retail_q1_demand_2010_summary.csv"
dfQ1_PA = pd.read_csv(fp)

# %%
dfQ1_PA.sum(axis=0).sort_values(ascending=False)[:10]
# Out:
# 37410     25301.0
# 21091     13630.0
# 21085     13588.0
# 21099     13283.0
# 85123A    12974.0
# 21980     12826.0
# 21092     12806.0
# 21212     12505.0
# 21984     12192.0
# 85220     11984.0
# dtype: float64

# %%
fi.get_frequent_items(frequent_items_error_type.NO_FALSE_POSITIVES)[:10]
# Out:
# [('37410', 77766, 72852, 77766),
#  ('21091', 42052, 37138, 42052),
#  ('21099', 41916, 37002, 41916),
#  ('21085', 41580, 36666, 41580),
#  ('21092', 40296, 35382, 40296),
#  ('85123A', 38922, 34008, 38922),
#  ('21980', 38484, 33570, 38484),
#  ('85220', 38127, 33213, 38127),
#  ('21212', 37515, 32601, 37515),
#  ('21984', 37358, 32444, 37358)]
