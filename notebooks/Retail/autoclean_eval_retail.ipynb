# %%
import pandas as pd
fp = "../../data/online_retail_II.csv"
df = pd.read_csv(fp)
# Out:
# /var/folders/fb/t_m5qpcj6qq85rvkh73vbxh40000gn/T/ipykernel_6102/4177313966.py:3: DtypeWarning: Columns (3,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp)

# %%
from AutoClean import AutoClean

# %%
pipeline = AutoClean(df, mode='manual', duplicates=False, missing_num="delete", missing_categ="delete", 
          encode_categ=False, extract_datetime=False, outliers=False, outlier_param=1.5, 
          logfile=True, verbose=True)
# Out:
# 25-11-2023 15:43:57.89 - INFO - Started validation of input parameters...
# 25-11-2023 15:43:57.90 - INFO - Completed validation of input parameters
# 25-11-2023 15:43:57.94 - INFO - Skipped handling of duplicates
# 25-11-2023 15:43:57.94 - INFO - Started handling of missing values...
# 25-11-2023 15:43:58.14 - INFO - Found a total of 247389 missing value(s)
# 25-11-2023 15:43:58.43 - INFO - Started handling of NUMERICAL missing values... Method: "DELETE"
# 25-11-2023 15:43:58.64 - DEBUG - Deletion of 0 NUMERIC missing value(s) succeeded
# 25-11-2023 15:43:58.64 - INFO - Started handling of CATEGORICAL missing values... Method: "DELETE"
# 25-11-2023 15:43:59.87 - DEBUG - Deletion of 247389 CATEGORICAL missing value(s) succeeded
# 25-11-2023 15:43:59.87 - INFO - Completed handling of missing values in 1.933645 seconds
# 25-11-2023 15:43:59.88 - INFO - Skipped handling of outliers
# 25-11-2023 15:43:59.89 - INFO - Skipped datetime feature conversion
# ...

# %%
pipeline.output
# Out:
#         Invoice StockCode                          Description Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS       12
# 1        489434    79323P                   PINK CHERRY LIGHTS       12
# 2        489434    79323W                  WHITE CHERRY LIGHTS       12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE        48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX       24
# ...         ...       ...                                  ...      ...
# 1067367  581587     22899         CHILDREN'S APRON DOLLY GIRL         6
# 1067368  581587     23254        CHILDRENS CUTLERY DOLLY GIRL         4
# 1067369  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE        4
# 1067370  581587     22138        BAKING SET 9 PIECE RETROSPOT         3
# 1067371  581587      POST                              POSTAGE        1
#
#            InvoiceDate Price Customer ID         Country
# ...
